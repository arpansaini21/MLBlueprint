# %% [markdown]
# ### Import Packages

# %%
from matplotlib import pyplot as plot
# can be importated as below also
# import matplotlib.pyplot as plt

# %% [markdown]
# ### defining panda dataframe

# %%
import pandas as pd
import numpy as np

# Sample data
data = {
    'product': [
        'Product A', 'Product B', 'Product C', 'Product D', 'Product E',
        'Product F', 'Product G', 'Product H', 'Product I', 'Product J',
        'Product K', 'Product L', 'Product M', 'Product N', 'Product O',
        'Product P', 'Product Q', 'Product R', 'Product S', 'Product T'
    ],
    'price': np.random.randint(100, 5001, size=20)  # Generate 20 random prices between 100 and 5000
}

# Creating the DataFrame
product_df = pd.DataFrame(data)

# Displaying the DataFrame
product_df.head()
# Out:
#      product  price
# 0  Product A   3789
# 1  Product B   4997
# 2  Product C   3375
# 3  Product D   4966
# 4  Product E   4969

# %%
bins = np.linspace(product_df['price'].min(axis=0),product_df['price'].max(axis=0),4 )
price_category = ['low','medium','high']
product_df['price_category'] = pd.cut(product_df['price'],bins,labels=price_category)

# %%
# we have added a third category of price_category based on the bins
product_df.head()
# Out:
#      product  price price_category
# 0  Product A   3789           high
# 1  Product B   4997           high
# 2  Product C   3375           high
# 3  Product D   4966           high
# 4  Product E   4969           high

# %% [markdown]
# ### Histogram
# - Visualization representation of countinous variable of data in categorical form.
# - x-axis represents the data bins, y-axis represents the number of elements in each of the bins.

# %%
plt.hist(product_df["price"],edgecolor='black')

# set x/y labels and plot title
plt.xlabel("price")
plt.ylabel("count")
plt.title("price bins")
# Out:
# Text(0.5, 1.0, 'price bins')

# %% [markdown]
# #### hist grams with given number of bins
#
# * dividing 20 elements into given 6 category and checking count in each category
# * notice Histor gram and bar graph created based on the custom categories created by bins has the same distribution

# %%
plt.hist(product_df["price"], bins = 3, edgecolor='black')

# set x/y labels and plot title
plt.xlabel("price")
plt.ylabel("count")
plt.title("price bins")
# Out:
# Text(0.5, 1.0, 'price bins')

# %% [markdown]
# ### Bar graph
#
# - no of elements in group_names should be equal to variable categories which we are ploting
# - 1 plt.bar(x,height, edgecolor='color_name',width=[0,1])
# - x is the categorical variable, and height is the number of values belonging to the category. You can adjust the width of each bin using an additional width argument in the function.
# - width = 1 means touching each other, less than 1 means start separating, greater than one , interfering with each other.
# - edgecolor='black' is adding the boder line

# %%
print('Bin Sizes')
print(bins)
print(product_df["price_category"].value_counts())
print(product_df["price_category"].value_counts().sort_values(axis=0))
group_names = product_df["price_category"].value_counts().sort_values(axis=0).index
plt.bar(group_names, product_df["price_category"].value_counts().sort_values(axis=0),edgecolor='black',width=0.9)

# set x/y labels and plot title
plt.xlabel("Price Category")
plt.ylabel("count")
plt.title("Price bins")
# Out:
# Bin Sizes
# [ 107. 1737. 3367. 4997.]
# high      10
# medium     6
# low        3
# Name: price_category, dtype: int64
# low        3
# medium     6
# high      10
# Name: price_category, dtype: int64
# Text(0.5, 1.0, 'Price bins')

# %% [markdown]
# #### we may assign incorrect category if you don't know the position of the value count as shown below

# %%
print('Bin Sizes')
print(bins)
print(product_df["price_category"].value_counts())
group_names = ['very cheap','cheap','costly']
pyplot.bar(group_names, product_df["price_category"].value_counts().sort_values(axis=0),edgecolor='black')

# set x/y labels and plot title
plt.xlabel("Price Category")
plt.ylabel("count")
plt.title("Price bins")
# Out:
# Bin Sizes
# [ 107. 1737. 3367. 4997.]
# high      10
# medium     6
# low        3
# Name: price_category, dtype: int64
# Text(0.5, 1.0, 'Price bins')

# %% [markdown]
# ### Box Plot | Descriptive Statistics | Data discribution & skewness
#
# * you can easily spot the outliers
# * you can see the discribution & Skewness of the data
# * Make it easy to compare between the groups
#
# <div>
# <img src="attachment:69e142cb-4fe1-4dad-81dd-3eb3ef226415.png", width="500" , height="500"><br><b> Fig 2 : Descriptive Statistics Box Plot Key Points</b></img>
#  </div>
# <br>
# <br>
#
# <h5> Box plot for categorical variable comparisions </h5>
#
#  <div>
# <img src="attachment:f2b82b7e-5cce-460f-95fa-5e73d911d820.png", width="500" , height="500"><br><b> Fig 2 : Category Comparisions using Box plots</b></img>
#  </div>

# %% [markdown]
# <div>
# <img src="attachment:69e3e759-6250-4dc5-8f77-23258b215751.png" width=200 height=200>
# </img>
# <div>

# %% [markdown]
# ###  Scatter Plots | Descriptive Statistics |  To check Relationship between two variables
#
# * Each observation represented as a point
# * Scatter plots show the relationship between two variables
# - predicator/Independent variables on x - axis. ( Engine Size)
# - Target/Depndent variables on Y - axis ( Price )
#
#
# **Example of Scater Plot :**
#
#  <div>
# <img src="attachment:bf1053e8-e834-4209-baa9-0dd5b0c84c97.png", width="500" , height="500"><br><b> Fig 3 : Scater plot to check relationship between engine size and Price</b></img>
#  </div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
used_cars_df = pd.read_csv('usedcars.csv')
used_cars_df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# get box blot of various categories with continous variable. 
sns.boxplot(x='body-style',y='price', data=used_cars_df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %% [markdown]
# ### Line Plot

# %%
# plt.plot(x,y)

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# <h2>Continuous Numerical Variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data. This will be useful later on for visualizing the fit of the simple linear regression model as well. </p>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

used_cars_df = pd.read_csv('usedcars.csv')
used_cars_df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# #### Negative Correlation Example

# %%
sns.regplot(x='highway-mpg',y='price',data=used_cars_df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
# Negative Correlation
used_cars_df[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# #### Positive Correlation Example

# %%
# Positive Correlation Method
sns.regplot(x="engine-size", y="price", data=used_cars_df)
plt.ylim(0,)
# Out:
# (0.0, 53416.443018230624)

# %%
used_cars_df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# #### Weak Correlation Example

# %%
sns.regplot(x="peak-rpm", y="price", data=used_cars_df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
used_cars_df[["peak-rpm", "price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# ### Pseudo Color Plot

# %% [markdown]
# A pseudocolor plot displays matrix data as an array of colored cells (known as faces). This plot is created as a flat surface in the x-y plane. The surface is defined by a grid of x and y coordinates that correspond to the corners (or vertices) of the faces. Matrix C specifies the colors at the vertices. The color of each face depends on the color of one of its four surrounding vertices. Of the four vertices, the one that comes first in the x-y grid determines the color of the face.
#
# In this course, you use the pcolor plot for visualizing the contents of a pivot table that has been grouped on the basis of 2 parameters. Those parameters then represent the x and y-axis components that create the grid. The values in the pivot table are the average values of a third parameter. These values act as the code for the color the cell is going to take.
#
# - You can define an additional cmap argument to specify the color scheme of the plot.

# %% [markdown]
# ## seaborn functions

# %% [markdown]
# ### Regression plot

# %% [markdown]
# A regression plot draws a scatter plot of two variables, x and y, and then fits the regression model and plots the resulting regression line along with a 95% confidence interval for that regression. The x and y parameters can be shared as the dataframe headers to be used, and the data frame itself is passed to the function as well.
#
# sns.regplot(x = 'header_1',y = 'header_2',data= df)

# %% [markdown]
# ### Box and whisker plot

# %% [markdown]
# ### Residual Plot

# %% [markdown]
# A residual plot is used to display the quality of polynomial regression. This function will regress y on x as a polynomial regression and then draw a scatterplot of the residuals.
# Residuals are the differences between the observed values of the dependent variable and the predicted values obtained from the regression model. In other words, a residual is a measure of how much a regression line vertically misses a data point, meaning how far off the predictions are from the actual data points.
#
#
# ```python
#
#     sns.residplot(data=df,x='header_1', y='header_2')
#     # alternative
#     sns.residplot(data=df,x='header_1', y='header_2')

# %% [markdown]
# ### KDE plot
#
# A Kernel Density Estimate (KDE) plot is a graph that creates a probability distribution curve for the data based upon its likelihood of occurrence on a specific value. This is created for a single vector of information. It is used in the course in order to compare the likely curves of the actual data with that of the predicted data.
#
# ```python
#
#     sns.kdeplot(X)

# %% [markdown]
# ### Distribution Plot
#
# This plot has the capacity to combine the histogram and the KDE plots. This plot creates the distribution curve using the bins of the histogram as a reference for estimation. You can optionally keep or discard the histogram from being displayed. In the context of the course, this plot can be used interchangeably with the KDE plot.
#
# ```python
#
# sns.distplot(X,hist=False)

# %% [markdown]
# ### Heat Map

# %%
import matplotlib.pyplot as plt


df_gptest = used_cars_df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels', columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot.fillna(0)
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(group_pivot,cmap='RdBu')
plt.colorbar()
plot.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
print(row_labels)
col_labels = grouped_pivot.index
print(col_labels)

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()
# Out:
# Index(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'], dtype='object', name='body-style')
# Index(['4wd', 'fwd', 'rwd'], dtype='object', name='drive-wheels')
