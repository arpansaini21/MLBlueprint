# %% [markdown]
# import datasets as ds
# ds.load_iris()

# %%
# split test and train
![image.png](attachment:9cdd46fa-5188-4d19-b369-1697017f5f70.png)

# %% [markdown]
# # Modeling (SVM with scikit learn)

# %% [markdown]
# ![image.png](attachment:0959fd29-1700-457a-b161-e45c2ef9eb51.png)

# %% [markdown]
# ![image.png](attachment:57a6890e-6012-4a36-8cf6-fb2c91f0bd8b.png)

# %% [markdown]
# ![image.png](attachment:591e65bd-33cb-4b6a-9a45-ac95b4848eec.png)

# %% [markdown]
# ![image.png](attachment:caa0c636-de12-4fe4-86b5-6724e275fc81.png)
